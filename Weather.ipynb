# %%
import requests
import datetime
import json
from pprint import pprint
url = 'https://api.darksky.net/forecast/***REMOVED***/55.833636,-4.279125?units=uk2'
retrieved = requests.get(url)

file = open('weatherdata.json','wb') 
 
file.write(retrieved.content) 
file.close()

# %%
with open('weatherdata.json') as data_file:    
    data = json.load(data_file)

# %%
pprint(data)
# Out:
# {'currently': {'apparentTemperature': 5.94,
#                'cloudCover': 0.68,
#                'dewPoint': 3.41,
#                'humidity': 0.74,
#                'icon': 'partly-cloudy-day',
#                'nearestStormBearing': 103,
#                'nearestStormDistance': 6,
#                'ozone': 389.08,
#                'precipIntensity': 0,
#                'precipProbability': 0,
#                'pressure': 1006.14,
#                'summary': 'Mostly Cloudy',
#                'temperature': 7.66,
#                'time': 1488814804,
#                'visibility': 7.36,
#                'windBearing': 228,
#                'windSpeed': 5.94},
#  'daily': {'data': [{'apparentTemperatureMax': 7.26,
#                      'apparentTemperatureMaxTime': 1488812400,
#                      'apparentTemperatureMin': 0.67,
#                      'apparentTemperatureMinTime': 1488769200,
#                      'cloudCover': 0.61,
#                      'dewPoint': 3.36,
# ...

# %%
epochtime = data["minutely"]["data"][30]["time"]
timeread =  datetime.datetime.fromtimestamp(epochtime).strftime('%c')
print(timeread)
precipprobability = data["minutely"]["data"][58]

pprint(precipprobability)
days = data["daily"]
pprint(days)
# Out:
# Mon Mar  6 16:10:00 2017
# {'precipIntensity': 0.7112,
#  'precipIntensityError': 0.8382,
#  'precipProbability': 0.09,
#  'precipType': 'rain',
#  'time': 1488818280}
# {'data': [{'apparentTemperatureMax': 7.26,
#            'apparentTemperatureMaxTime': 1488812400,
#            'apparentTemperatureMin': 0.67,
#            'apparentTemperatureMinTime': 1488769200,
#            'cloudCover': 0.61,
#            'dewPoint': 3.36,
#            'humidity': 0.85,
#            'icon': 'rain',
#            'moonPhase': 0.29,
#            'ozone': 391.7,
#            'precipIntensity': 0.0889,
#            'precipIntensityMax': 0.4877,
#            'precipIntensityMaxTime': 1488837600,
#            'precipProbability': 0.6,
#            'precipType': 'rain',
#            'pressure': 1002.79,
#            'summary': 'Light rain starting in the afternoon.',
#            'sunriseTime': 1488783417,
#            'sunsetTime': 1488823360,
#            'temperatureMax': 8.76,
# ...

# %%
# Out:
# {'apparentTemperature': 2.96,
#  'cloudCover': 0.57,
#  'dewPoint': 2.83,
#  'humidity': 0.86,
#  'icon': 'partly-cloudy-night',
#  'ozone': 400.13,
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'pressure': 1012.39,
#  'summary': 'Partly Cloudy',
#  'temperature': 5.04,
#  'time': 1488841200,
#  'visibility': 10,
#  'windBearing': 226,
#  'windSpeed': 5.57}
